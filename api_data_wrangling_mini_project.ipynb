# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'PgCGPr3aEMoqLs4tXh-d'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
url = 'https://www.quandl.com/api/v3/datasets'

# %%
params = dict(database_code='XFRA',
              dataset_code='AFX_X',
              start_date='2017-01-01',
              end_date='2017-12-31',
              return_format ='json',
              api_key=API_KEY)

# %% [markdown]
# Note: API's can change a bit with each version, for this exercise it is reccomended to use the "V3" quandl api at `https://www.quandl.com/api/v3/`

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
r = requests.get(url,params)

# %%
print(r.status_code)
# Out:
# 200

# %%
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %%
print(r.headers)
# Out:
# {'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': '*', 'Access-Control-Allow-Methods': 'GET, POST, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'X-RateLimit-Limit, X-RateLimit-Remaining', 'Access-Control-Max-Age': '1728000', 'Allow': 'GET, HEAD, POST, PUT, DELETE, OPTIONS, PATCH', 'Cache-Control': 'no-store', 'Content-Encoding': 'gzip', 'Content-Security-Policy': "frame-ancestors 'self';", 'Content-Type': 'application/json; charset=utf-8', 'Date': 'Mon, 05 Jul 2021 19:46:31 GMT', 'ETag': 'W/"e11aa4ce481f447acd052ff645b95ab6"', 'Pragma': 'no-cache', 'Referrer-Policy': 'origin-when-cross-origin', 'Server': 'openresty', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Vary': 'Origin', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'X-Rack-CORS': 'miss; no-origin', 'X-RateLimit-Limit': '50000', 'X-RateLimit-Remaining': '49994', 'X-Request-Id': '161f23dd-b780-4fd9-8419-dcfcc3d16013', 'X-Runtime': '0.220654', 'X-XSS-Protection': '1; mode=block', 'Content-Length': '4130', 'Connection': 'keep-alive', 'Set-Cookie': 'visid_incap_2261005=qnvJZ8/QRXOOvl5jL+fe/pdh42AAAAAAQUIPAAAAAADhuyJ/iw7Vuu/vicKTN5ru; expires=Tue, 05 Jul 2022 06:54:10 GMT; HttpOnly; path=/; Domain=.quandl.com; Secure; SameSite=None, nlbi_2261005=2A8TLKtT1FiFEf8ygSMXTwAAAAAJgX2hkix7vR9O9KmffVTx; path=/; Domain=.quandl.com; Secure; SameSite=None, incap_ses_9076_2261005=LJ9hCPJmD2j3o6lmGG70fZdh42AAAAAA3ZxI2BQd3UYj4dLipExgDg==; path=/; Domain=.quandl.com; Secure; SameSite=None', 'X-CDN': 'Imperva', 'X-Iinfo': '7-21644535-21644537 NNNN CT(6 8 0) RT(1625514391660 59) q(0 0 0 -1) r(2 2) U2'}

# %%
r.text
# Out:
# '{"datasets":[{"id":49333665,"dataset_code":"5PH","database_code":"XFRA","name":"Gemfields Group Limited (5PH) Adjusted Stock Prices","description":" \\u003cb\\u003eTicker\\u003c/b\\u003e: 5PH \\u003cbr\\u003e \\u003cbr\\u003e \\u003cb\\u003eExchange\\u003c/b\\u003e: XFRA \\u003cbr\\u003e \\u003cbr\\u003e Columns: \\u003cbr\\u003e \\u003cbr\\u003e Open,High,Low,Close,Volume are adjusted and shown in EUR currency. \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.","refreshed_at":"2021-07-03T04:51:31.925Z","newest_available_date":"2021-07-02","oldest_available_date":"2020-02-12","column_names":["Date","Open","High","Low","Close","Volume","Adjustment Factor","Adjustment Type"],"frequency":"daily","type":"Time Series","premium":true,"database_id":15302},{"id":49333664,"dataset_code":"9HB0","database_code":"XFRA","name":"Komo Plant Based Foods Inc (9HB0) Adjusted Stock Prices","description":" \\u003cb\\u003eTicker\\u003c/b\\u003e: 9HB0 \\u003cbr\\u003e \\u003cbr\\u003e \\u003cb\\u003eExchange\\u003c/b\\u003e: XFRA \\u003cbr\\u003e \\u003cbr\\u003e Columns: \\u003cbr\\u003e \\u003cbr\\u003e Open,High,Low,Close,Volume are adjusted and shown in EUR currency. \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.","refreshed_at":"2021-07-03T04:51:31.925Z","newest_available_date":"2021-07-02","oldest_available_date":"2020-02-12","column_names":["Date","Open","High","Low","Close","Volume","Adjustment Factor","Adjustment Type"],"frequency":"daily","type":"Time Series","premium":true,"database_id":15302},{"id":49333663,"dataset_code":"48H_UADJ","database_code":"XFRA","name":"Calisen Plc (48H) Unadjusted Stock Prices","description":" \\u003cb\\u003eTicker\\u003c/b\\u003e: 48H \\u003cbr\\u003e \\u003cbr\\u003e \\u003cb\\u003eExchange\\u003c/b\\u003e: XFRA \\u003cbr\\u003e \\u003cbr\\u003e Columns: \\u003cbr\\u003e \\u003cbr\\u003e Open,High,Low,Close,Volume are unadjusted and shown in EUR currency. \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.","refreshed_at":"2021-03-27T05:12:30.246Z","newest_available_date":"2021-03-11","oldest_available_date":"2020-02-12","column_names":["Date","Open","High","Low","Close","Volume","Adjustment Factor","Adjustment Type"],"frequency":"daily","type":"Time Series","premium":true,"database_id":15302},{"id":49333662,"dataset_code":"48H","database_code":"XFRA","name":"Calisen Plc (48H) Adjusted Stock Prices","description":" \\u003cb\\u003eTicker\\u003c/b\\u003e: 48H \\u003cbr\\u003e \\u003cbr\\u003e \\u003cb\\u003eExchange\\u003c/b\\u003e: XFRA \\u003cbr\\u003e \\u003cbr\\u003e Columns: \\u003cbr\\u003e \\u003cbr\\u003e Open,High,Low,Close,Volume are adjusted and shown in EUR currency. \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Factor shows the factor by which prices are adjusted on days which adjustments take place \\u003cbr\\u003e \\u003cbr\\u003e Adjustment Type is a number representing the type of adjustment. Refer to documentation for more information on these codes.","refreshed_at":"2021-03-27T05:12:30.246Z","newest_available_date":"2021-03-11","oldest_available_date":"2020-02-12","column_names":["Date","Open","High","Low","Close","Volume","Adjustment Factor","Adjustment Type"],"frequency":"daily","type":"Time Series","premium":true,"database_id":15302},{"id":49333661,"dataset_code":"9HB0 ...

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
json_data=r.json()

# %%
print(type(json_data))
# Out:
# <class 'dict'>

# %%
print(json_data.keys())
# Out:
# dict_keys(['datasets', 'meta'])

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
